# %% [markdown]
# # Ipywidgets

# %% [markdown]
# **ipywidgets** es un biblioteca que que permite hacer gráficos interactivos basados en `matplotlib`.
# Con la función **interact** se crean controles interactivos.

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np

# %%
# instalar ipywidgets con pip
#from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %% [markdown]
# $$ f(x) = 2x  \sin(2 \pi x)$$

# %%
x = np.linspace(0,3, num=300)
y = 2 * x * np.sin(2 * np.pi * x)
plt.plot(x, y, color = '#FFB74D')

# %%
freq = 2*np.pi

x = np.linspace(0,3, num=200)
y = x * np.sin(freq * x)
plt.plot(x, y, color = '#FFB74D')

# %%
def pinta_funcion(freq):
    x = np.linspace(0,3, num=200)
    y = x * np.sin(freq * x)
    plt.plot(x, y, color = '#FFB74D' )
    plt.ylim(-5, 5)
    plt.title(u"Grafica de funcion")

# %%
pinta_funcion(2 * np.pi)

# %%
interact(pinta_funcion, freq=(2 * np.pi, 2 * np.pi * 10.0))
# Out:
# interactive(children=(FloatSlider(value=34.55751918948772, description='freq', max=62.83185307179586, min=6.28…
# <function __main__.pinta_funcion(freq)>

# %% [markdown]
# ## Basic interact

# %%
def f(x):
    print(x)

# %%
interact(f, x = 10)
# Out:
# interactive(children=(IntSlider(value=10, description='x', max=30, min=-10), Output()), _dom_classes=('widget-…
# <function __main__.f(x)>

# %%
interact(f, x = True)
# Out:
# interactive(children=(Checkbox(value=True, description='x'), Output()), _dom_classes=('widget-interact',))
# <function __main__.f(x)>

# %%
interact(f, x = "default")
# Out:
# interactive(children=(Text(value='default', description='x'), Output()), _dom_classes=('widget-interact',))
# <function __main__.f(x)>

# %%
# con decoradores
@interact(x = True, y = 1.0)
def g(x, y):
    print(x, y)
# Out:
# interactive(children=(Checkbox(value=True, description='x'), FloatSlider(value=1.0, description='y', max=3.0, …

# %%
def h(p,q):
    print (p, q)

# %%
interact(h, p = 5, q = fixed(20))
# Out:
# interactive(children=(IntSlider(value=5, description='p', max=15, min=-5), Output()), _dom_classes=('widget-in…
# <function __main__.h(p, q)>

# %%
interact(f, x=widgets.IntSlider(min = -10, max = 30, step = 2, value = 10));
# Out:
# interactive(children=(IntSlider(value=10, description='x', max=30, min=-10, step=2), Output()), _dom_classes=(…
